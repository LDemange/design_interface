# %%
import numpy as np

# %%
np.cos(0)
# Out:
# 1.0

# %%
x=np.linspace(-10,10,100)

# %%
#y=list(map(np.sin,x))
#y=list(map(np.sin,x))sqrt()
np.heaviside(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13677/2183412388.py in <module>
#       1 #y=list(map(np.sin,x))
#       2 #y=list(map(np.sin,x))sqrt()
# ----> 3 np.heaviside(x)
#
# TypeError: heaviside() takes from 2 to 3 positional arguments but 1 were given

# %%
y
# Out:
# [0.5440211108893698,
#  0.3645987336558887,
#  0.1703468323280965,
#  -0.03083367906114098,
#  -0.23076007532505177,
#  -0.4213006405886069,
#  -0.5947054140244975,
#  -0.7439214082568444,
#  -0.8628794793817836,
#  -0.9467411805833543,
#  -0.9920955589323228,
#  -0.9970978909438748,
#  -0.9615447140268237,
#  -0.8868821020290788,
#  -0.7761468482835805,
#  -0.6338429484489058,
#  -0.46575840702565247,
#  -0.27872981867755725,
#  -0.08036429967028173,
#  0.12126992053716677,
#  0.31797166281061867,
#  0.5017403693939113,
#  0.6651015149788224,
#  0.8014106221689697,
#  0.9051235159501367,
#  0.9720218249588334,
#  0.9993845576124357,
#  0.9860987744909298,
#  0.9327048555318336,
#  0.8413745208608705,
#  0.7158224992291902,
#  0.5611554368152021,
#  0.38366419180611233,
#  0.19056796287548494,
#  -0.010279341240534253,
#  -0.2107085480771929,
#  -0.40256749066949615,
#  -0.5780525851065732,
#  -0.7300262299764461,
#  -0.8523071179396752,
#  -0.9399216514301314,
# ...
